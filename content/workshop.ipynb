# %% [markdown]
# # <img src="/python-workshop/images/urcf-logo.png" alt="URCF Logo" width="500">
#
# # Introduction to Python workshop
#
# Welcome to the URCF Introduction to Python workshop!
#
# The page you're looking at now is called a "Jupyter Notebook". It's an interactive environment for computing with Python.
#
# The code in Jupyter Notebooks is split into sections called "cells", which can be edited and executed independently. To run the code in a cell and see the results, click into the cell and press `Shift+Enter`. Try it out below! If the code executes and you can see a sine wave plot, you're all set for the workshop! It may take a while to import the necessary libraries the first time, so be patient.

# %%
# Click into this cell and press `Shift+Enter` to run the code.
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
